# %%
file = open("ganesh text.txt", "r")

# %%
file=open("ganesh text.txt","r")
for x in file:
    a = x;
    alphanumeric = " "

    for character in a:
        if character.isalnum():
            alphanumeric += character
    print(alphanumeric)
# Out:
#  ...
